# %%
import pandas as pd

# %%
df_users = pd.read_csv('./data/users.csv')
df_users_status = pd.read_csv('./data/users_status.csv')

# %%
df_users.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age
# 0      Glenda.Pyle@gmail.com  firefighter  25.0
# 1     Hollie.Allys@gmail.com       worker  26.0
# 2     Grier.Henrie@gmail.com       doctor  23.0
# 3  Kittie.Strephon@gmail.com       worker  45.0
# 4    Kassey.Prober@gmail.com       worker  45.0

# %%
df_users_status.head()
# Out:
#     id  active
# 0  100       0
# 1  101       1
# 2  102       0
# 3  103       1
# 4  104       0

# %%
df_inner_join = pd.merge(
    df_users,
    df_users_status,
    on='id',
    how='inner'
)

# %%
df_inner_join.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age  active
# 0      Glenda.Pyle@gmail.com  firefighter  25.0       0
# 1     Hollie.Allys@gmail.com       worker  26.0       1
# 2     Grier.Henrie@gmail.com       doctor  23.0       0
# 3  Kittie.Strephon@gmail.com       worker  45.0       1
# 4    Kassey.Prober@gmail.com       worker  45.0       0

# %%
df_left_join = pd.merge(
    df_users,
    df_users_status,
    on='id',
    how='left'
)

# %%
df_left_join.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age  active
# 0      Glenda.Pyle@gmail.com  firefighter  25.0     0.0
# 1     Hollie.Allys@gmail.com       worker  26.0     1.0
# 2     Grier.Henrie@gmail.com       doctor  23.0     0.0
# 3  Kittie.Strephon@gmail.com       worker  45.0     1.0
# 4    Kassey.Prober@gmail.com       worker  45.0     0.0
